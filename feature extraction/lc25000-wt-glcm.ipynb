# %%
# Core Python libraries
import os
import time
import shutil
import pathlib
import itertools
import tempfile

# Data manipulation and visualization
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Image processing
from PIL import Image
import cv2
from skimage.feature import graycomatrix, graycoprops

# Machine Learning models and preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

# Machine Learning classifiers
from sklearn.ensemble import (
    RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier,
    ExtraTreesClassifier, BaggingClassifier, StackingClassifier,
    VotingClassifier, HistGradientBoostingClassifier
)
from sklearn.svm import SVC
from sklearn.linear_model import (
    LogisticRegression, SGDClassifier, RidgeClassifier, PassiveAggressiveClassifier,
    Perceptron
)
from sklearn.neighbors import KNeighborsClassifier, NearestCentroid
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import (
    GaussianNB, BernoulliNB, MultinomialNB, ComplementNB
)
from sklearn.neural_network import MLPClassifier
from sklearn.discriminant_analysis import (
    LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
)
from sklearn.calibration import CalibratedClassifierCV
from sklearn.dummy import DummyClassifier
from sklearn.multiclass import OneVsRestClassifier

# External libraries
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# ML Evaluation metrics
from sklearn.metrics import (
    confusion_matrix, accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, jaccard_score, matthews_corrcoef,
    cohen_kappa_score, roc_curve, classification_report
)

# Deep Learning (TensorFlow/Keras)
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.optimizers import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, 
    BatchNormalization
)
from tensorflow.keras.callbacks import *
from tensorflow.keras import regularizers
from tensorflow.keras.metrics import *

# Word Document handling
# from docx import Document
# from docx.shared import Inches

# IPython display utilities
from IPython.display import display, HTML

# %%
# In[3]:


sns.set_theme(style='darkgrid', palette='pastel')
color = sns.color_palette(palette='pastel')


# # 2. Load images from the dataset
# in this part will do the following
# * only the 40X zoom will be selected
# * each file path will be stored in the variable ***filepaths*** and the crosponding label in the variable ***labels*** in the same index.
# * create a data frame ***df*** to work like excel sheet with columnes filepath and label.
# * show sample of the dataframe.

# In[10]:


import numpy as np
import pywt
from skimage.feature import graycomatrix, graycoprops
from tqdm import tqdm  # For progress bar

def compute_glcm_features(image):
    distances = [1, 2, 3, 4]  # You can experiment with different distances
    angles = [0, np.pi/4, np.pi/2, 3*np.pi/4]  # You can experiment with different angles

    # Apply 2D Discrete Wavelet Transform (DWT)
    coeffs = pywt.wavedec2(image, 'db1', level=2)  # Decomposition up to 2 levels
    cA, (cH1, cV1, cD1), (cH2, cV2, cD2) = coeffs  # Extract subbands

    # Function to compute GLCM and extract features
    def extract_glcm_features(subband):
        glcm = graycomatrix(subband, distances=distances, angles=angles, levels=256, symmetric=True, normed=True)
        contrast = graycoprops(glcm, 'contrast').ravel()
        energy = graycoprops(glcm, 'energy').ravel()
        homogeneity = graycoprops(glcm, 'homogeneity').ravel()
        correlation = graycoprops(glcm, 'correlation').ravel()
        entropy = -np.sum(glcm * np.log(glcm + 1e-10))  # Compute entropy manually
        return np.concatenate((contrast, energy, homogeneity, correlation, [entropy]))

    # Extract GLCM features for each wavelet subband
    features = []
    for subband in [cA, cH1, cV1, cD1, cH2, cV2, cD2]:
        features.append(extract_glcm_features(subband.astype(np.uint8)))  # Convert float to uint8 for GLCM

    return np.concatenate(features)  # Concatenate all extracted features


def process_one_image(path):
    image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    return compute_glcm_features(image)

def load_and_compute_glcm_features(paths):
    features = []
    total = len(paths)
    for i, path in enumerate(tqdm(paths, desc="Processing Images", unit="img")):
        image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        dwt_features = compute_glcm_features(image)
        features.append(dwt_features)
    return np.array(features)

from joblib import Parallel, delayed
from tqdm import tqdm
import numpy as np

def par_load_and_compute_glcm_features(paths, n_jobs=-1):
    # n_jobs=-1 uses all available CPU cores
    results = Parallel(n_jobs=n_jobs)(
        delayed(process_one_image)(p) for p in tqdm(paths, desc="Processing Images", unit="img")
    )
    return np.vstack(results)

# %%
import pandas as pd
from pathlib import Path

ROOT = Path("/kaggle/input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set")
img_exts = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"}

paths = [p for p in ROOT.rglob("*") if p.suffix.lower() in img_exts]

def infer_organ(p: Path) -> str:
    s = p.as_posix().lower()
    if "/lung_image_sets/" in s:
        return "lung"
    if "/colon_image_sets/" in s:
        return "colon"
    return "unknown"

df = pd.DataFrame({
    "path": [str(p) for p in paths],
    "organ": [infer_organ(p) for p in paths],
    "class_name": [p.parent.name for p in paths],
})

df = df.sort_values(["organ", "class_name", "path"]).reset_index(drop=True)

print(df.head(10))
print("\nOrgan counts:\n", df["organ"].value_counts())
print("\nOrgan x class:\n", pd.crosstab(df["organ"], df["class_name"]))

paths = df["path"]
#   Adjust the label column name if needed (e.g., 'class', 'target')
# labels = df_fold1["label"].to_numpy()

# 5) Compute GLCM features
features = par_load_and_compute_glcm_features(paths)

# 'features' corresponds to GLCM features per image in 'paths'
# 'labels' are the ground-truth labels for those images


# In[13]:
# Out:
#                                                 path  organ class_name
# 0  /kaggle/input/lung-and-colon-cancer-histopatho...  colon  colon_aca
# 1  /kaggle/input/lung-and-colon-cancer-histopatho...  colon  colon_aca
# 2  /kaggle/input/lung-and-colon-cancer-histopatho...  colon  colon_aca
# 3  /kaggle/input/lung-and-colon-cancer-histopatho...  colon  colon_aca
# 4  /kaggle/input/lung-and-colon-cancer-histopatho...  colon  colon_aca
# 5  /kaggle/input/lung-and-colon-cancer-histopatho...  colon  colon_aca
# 6  /kaggle/input/lung-and-colon-cancer-histopatho...  colon  colon_aca
# 7  /kaggle/input/lung-and-colon-cancer-histopatho...  colon  colon_aca
# 8  /kaggle/input/lung-and-colon-cancer-histopatho...  colon  colon_aca
# 9  /kaggle/input/lung-and-colon-cancer-histopatho...  colon  colon_aca
#
# Organ counts:
#  organ
# lung     15000
# colon    10000
# Name: count, dtype: int64
#
# Organ x class:
#  class_name  colon_aca  colon_n  lung_aca  lung_n  lung_scc
# organ
# colon            5000     5000         0       0         0
# lung                0        0      5000    5000      5000
# Processing Images:   0%|          | 0/25000 [00:00<?, ?img/s]
#
#
# Processing Images:   0%|          | 8/25000 [00:02<1:53:06,  3.68img/s]
#
#
# Processing Images:   0%|          | 12/25000 [00:03<2:08:48,  3.23img/s]
#
#
# Processing Images:   0%|          | 16/25000 [00:05<2:15:16,  3.08img/s]
#
#
# Processing Images:   0%|          | 20/25000 [00:06<2:19:23,  2.99img/s]
#
#
# Processing Images:   0%|          | 24/25000 [00:07<2:26:42,  2.84img/s]
#
#
# Processing Images:   0%|          | 28/25000 [00:09<2:25:55,  2.85img/s]
#
#
# Processing Images:   0%|          | 32/25000 [00:10<2:25:00,  2.87img/s]
#
#
# Processing Images:   0%|          | 36/25000 [00:12<2:25:40,  2.86img/s]
#
#
# Processing Images:   0%|          | 40/25000 [00:13<2:25:28,  2.86img/s]
#
#
# Processing Images:   0%|          | 44/25000 [00:14<2:24:50,  2.87img/s]
#
#
# Processing Images:   0%|          | 48/25000 [00:16<2:25:51,  2.85img/s]
#
#
# Processing Images:   0%|          | 52/25000 [00:17<2:27:28,  2.82img/s]
#
#
# Processing Images:   0%|          | 56/25000 [00:19<2:27:42,  2.81img/s]
#
#
# Processing Images:   0%|          | 60/25000 [00:20<2:27:27,  2.82img/s]
#
#
# Processing Images:   0%|          | 64/25000 [00:22<2:26:19,  2.84img/s]
#
#
# Processing Images:   0%|          | 68/25000 [00:23<2:25:59,  2.85img/s]
#
#
# Processing Images:   0%|          | 72/25000 [00:24<2:25:53,  2.85img/s]
#
#
# Processing Images:   0%|          | 76/25000 [00:26<2:25:58,  2.85img/s]
#
#
# Processing Images:   0%|          | 80/25000 [00:27<2:28:17,  2.80img/s]
#
#
# Processing Images:   0%|          | 84/25000 [00:29<2:27:30,  2.82img/s]
#
#
# Processing Images:   0%|          | 88/25000 [00:30<2:28:25,  2.80img/s]
#
#
# Processing Images:   0%|          | 92/25000 [00:32<2:28:32,  2.79img/s]
#
#
# Processing Images:   0%|          | 96/25000 [00:33<2:28:41,  2.79img/s]
#
#
# Processing Images:   0%|          | 100/25000 [00:34<2:28:19,  2.80img/s]
#
#
# Processing Images:   0%|          | 104/25000 [00:36<2:28:38,  2.79img/s]
#
#
# Processing Images:   0%|          | 108/25000 [00:37<2:30:21,  2.76img/s]
#
#
# Processing Images:   0%|          | 112/25000 [00:39<2:31:00,  2.75img/s]
#
#
# Processing Images:   0%|          | 116/25000 [00:40<2:30:17,  2.76img/s]
#
#
# Processing Images:   0%|          | 120/25000 [00:42<2:30:17,  2.76img/s]
#
#
# Processing Images:   0%|          | 124/25000 [00:43<2:29:50,  2.77img/s]
#
#
# Processing Images:   1%|          | 128/25000 [00:45<2:28:58,  2.78img/s]
#
#
# Processing Images:   1%|          | 132/25000 [00:46<2:27:59,  2.80img/s]
#
#
# Processing Images:   1%|          | 136/25000 [00:47<2:31:44,  2.73img/s]
#
#
# Processing Images:   1%|          | 140/25000 [00:49<2:30:36,  2.75img/s]
#
#
# Processing Images:   1%|          | 144/25000 [00:50<2:28:41,  2.79img/s]
#
#
# Processing Images:   1%|          | 148/25000 [00:52<2:26:51,  2.82img/s]
#
#
# Processing Images:   1%|          | 152/25000 [00:53<2:25:44,  2.84img/s]
#
#
# Processing Images:   1%|          | 156/25000 [00:54<2:25:07,  2.85img/s]
#
#
# Processing Images:   1%|          | 160/25000 [00:56<2:25:23,  2.85img/s]
#
#
# Processing Images:   1%|          | 164/25000 [00:57<2:26:41,  2.82img/s]
#
#
# Processing Images:   1%|          | 168/25000 [00:59<2:27:42,  2.80img/s]
#
#
# Processing Images:   1%|          | 172/25000 [01:00<2:26:04,  2.83img/s]
#
#
# Processing Images:   1%|          | 176/25000 [01:02<2:25:46,  2.84img/s]
#
#
# Processing Images:   1%|          | 180/25000 [01:03<2:24:59,  2.85img/s]
#
#
# Processing Images:   1%|          | 184/25000 [01:04<2:24:44,  2.86img/s]
#
#
# Processing Images:   1%|          | 188/25000 [01:06<2:25:30,  2.84img/s]
#
#
# Processing Images:   1%|          | 192/25000 [01:07<2:29:10,  2.77img/s]
#
#
# Processing Images:   1%|          | 196/25000 [01:09<2:32:22,  2.71img/s]
#
#
# Processing Images:   1%|          | 200/25000 [01:10<2:31:01,  2.74img/s]
#
#
# Processing Images:   1%|          | 204/25000 [01:12<2:28:29,  2.78img/s]
#
#
# Processing Images:   1%|          | 208/25000 [01:13<2:28:09,  2.79img/s]
#
#
# Processing Images:   1%|          | 212/25000 [01:15<2:28:33,  2.78img/s]
#
#
# Processing Images:   1%|          | 216/25000 [01:16<2:28:01,  2.79img/s]
#
#
# Processing Images:   1%|          | 220/25000 [01:17<2:29:47,  2.76img/s]
#
#
# Processing Images:   1%|          | 224/25000 [01:19<2:29:20,  2.76img/s]
#
#
# Processing Images:   1%|          | 228/25000 [01:20<2:28:42,  2.78img/s]
#
#
# Processing Images:   1%|          | 232/25000 [01:22<2:28:01,  2.79img/s]
#
#
# Processing Images:   1%|          | 236/25000 [01:23<2:28:46,  2.77img/s]
#
#
# Processing Images:   1%|          | 240/25000 [01:25<2:28:26,  2.78img/s]
#
#
# Processing Images:   1%|          | 244/25000 [01:26<2:27:25,  2.80img/s]
#
#
# Processing Images:   1%|          | 248/25000 [01:27<2:27:32,  2.80img/s]
#
#
# Processing Images:   1%|          | 252/25000 [01:29<2:26:59,  2.81img/s]
#
#
# Processing Images:   1%|          | 256/25000 [01:30<2:26:44,  2.81img/s]
#
#
# Processing Images:   1%|          | 260/25000 [01:32<2:26:16,  2.82img/s]
#
#
# Processing Images:   1%|          | 264/25000 [01:33<2:26:26,  2.82img/s]
#
#
# Processing Images:   1%|          | 268/25000 [01:35<2:25:59,  2.82img/s]
#
#
# Processing Images:   1%|          | 272/25000 [01:36<2:26:29,  2.81img/s]
#
#
# Processing Images:   1%|          | 276/25000 [01:37<2:28:00,  2.78img/s]
#
#
# Processing Images:   1%|          | 280/25000 [01:39<2:27:29,  2.79img/s]
#
#
# Processing Images:   1%|          | 284/25000 [01:40<2:25:59,  2.82img/s]
#
#
# Processing Images:   1%|          | 288/25000 [01:42<2:25:37,  2.83img/s]
#
#
# Processing Images:   1%|          | 292/25000 [01:43<2:25:41,  2.83img/s]
#
#
# Processing Images:   1%|          | 296/25000 [01:44<2:24:47,  2.84img/s]
#
#
# Processing Images:   1%|          | 300/25000 [01:46<2:24:37,  2.85img/s]
#
#
# Processing Images:   1%|          | 304/25000 [01:47<2:26:23,  2.81img/s]
#
#
# Processing Images:   1%|          | 308/25000 [01:49<2:25:51,  2.82img/s]
#
#
# Processing Images:   1%|          | 312/25000 [01:50<2:25:36,  2.83img/s]
#
#
# Processing Images:   1%|▏         | 316/25000 [01:52<2:24:56,  2.84img/s]
#
#
# Processing Images:   1%|▏         | 320/25000 [01:53<2:24:44,  2.84img/s]
#
#
# Processing Images:   1%|▏         | 324/25000 [01:54<2:24:34,  2.84img/s]
#
#
# Processing Images:   1%|▏         | 328/25000 [01:56<2:23:48,  2.86img/s]
#
#
# Processing Images:   1%|▏         | 332/25000 [01:57<2:25:41,  2.82img/s]
#
#
# Processing Images:   1%|▏         | 336/25000 [01:59<2:25:33,  2.82img/s]
#
#
# Processing Images:   1%|▏         | 340/25000 [02:00<2:25:33,  2.82img/s]
#
#
# Processing Images:   1%|▏         | 344/25000 [02:01<2:24:56,  2.84img/s]
#
#
# Processing Images:   1%|▏         | 348/25000 [02:03<2:25:02,  2.83img/s]
#
#
# Processing Images:   1%|▏         | 352/25000 [02:04<2:25:00,  2.83img/s]
#
#
# Processing Images:   1%|▏         | 356/25000 [02:06<2:24:44,  2.84img/s]
#
#
# Processing Images:   1%|▏         | 360/25000 [02:07<2:26:54,  2.80img/s]
#
#
# Processing Images:   1%|▏         | 364/25000 [02:09<2:26:11,  2.81img/s]
#
#
# Processing Images:   1%|▏         | 368/25000 [02:10<2:26:19,  2.81img/s]
#
#
# Processing Images:   1%|▏         | 372/25000 [02:11<2:25:01,  2.83img/s]
#
#
# Processing Images:   2%|▏         | 376/25000 [02:13<2:24:47,  2.83img/s]
#
#
# Processing Images:   2%|▏         | 380/25000 [02:14<2:25:14,  2.83img/s]
#
#
# Processing Images:   2%|▏         | 384/25000 [02:16<2:24:50,  2.83img/s]
#
#
# Processing Images:   2%|▏         | 388/25000 [02:17<2:25:42,  2.82img/s]
#
#
# Processing Images:   2%|▏         | 392/25000 [02:18<2:24:53,  2.83img/s]
#
#
# Processing Images:   2%|▏         | 396/25000 [02:20<2:24:43,  2.83img/s]
#
#
# Processing Images:   2%|▏         | 400/25000 [02:21<2:24:48,  2.83img/s]
#
#
# Processing Images:   2%|▏         | 404/25000 [02:23<2:24:24,  2.84img/s]
#
#
# Processing Images:   2%|▏         | 408/25000 [02:24<2:24:28,  2.84img/s]
#
#
# Processing Images:   2%|▏         | 412/25000 [02:25<2:24:31,  2.84img/s]
#
#
# Processing Images:   2%|▏         | 416/25000 [02:27<2:25:02,  2.82img/s]
#
#
# Processing Images:   2%|▏         | 420/25000 [02:28<2:24:59,  2.83img/s]
#
#
# Processing Images:   2%|▏         | 424/25000 [02:30<2:24:26,  2.84img/s]
#
#
# Processing Images:   2%|▏         | 428/25000 [02:31<2:23:58,  2.84img/s]
#
#
# Processing Images:   2%|▏         | 432/25000 [02:32<2:24:23,  2.84img/s]
#
#
# Processing Images:   2%|▏         | 436/25000 [02:34<2:24:52,  2.83img/s]
#
#
# Processing Images:   2%|▏         | 440/25000 [02:35<2:25:13,  2.82img/s]
#
#
# Processing Images:   2%|▏         | 444/25000 [02:37<2:25:44,  2.81img/s]
#
#
# Processing Images:   2%|▏         | 448/25000 [02:38<2:24:48,  2.83img/s]
#
#
# Processing Images:   2%|▏         | 452/25000 [02:40<2:24:00,  2.84img/s]
#
#
# Processing Images:   2%|▏         | 456/25000 [02:41<2:24:05,  2.84img/s]
#
#
# Processing Images:   2%|▏         | 460/25000 [02:42<2:24:52,  2.82img/s]
#
#
# Processing Images:   2%|▏         | 464/25000 [02:44<2:25:18,  2.81img/s]
#
#
# Processing Images:   2%|▏         | 468/25000 [02:45<2:25:21,  2.81img/s]
#
#
# Processing Images:   2%|▏         | 472/25000 [02:47<2:27:15,  2.78img/s]
#
#
# Processing Images:   2%|▏         | 476/25000 [02:48<2:27:05,  2.78img/s]
#
#
# Processing Images:   2%|▏         | 480/25000 [02:50<2:27:29,  2.77img/s]
#
#
# Processing Images:   2%|▏         | 484/25000 [02:51<2:27:34,  2.77img/s]
#
#
# Processing Images:   2%|▏         | 488/25000 [02:53<2:26:17,  2.79img/s]
#
#
# Processing Images:   2%|▏         | 492/25000 [02:54<2:26:01,  2.80img/s]
#
#
# Processing Images:   2%|▏         | 496/25000 [02:55<2:26:12,  2.79img/s]
#
#
# Processing Images:   2%|▏         | 500/25000 [02:57<2:27:06,  2.78img/s]
#
#
# Processing Images:   2%|▏         | 504/25000 [02:58<2:27:44,  2.76img/s]
#
#
# Processing Images:   2%|▏         | 508/25000 [03:00<2:27:10,  2.77img/s]
#
#
# Processing Images:   2%|▏         | 512/25000 [03:01<2:26:49,  2.78img/s]
#
#
# Processing Images:   2%|▏         | 516/25000 [03:03<2:26:26,  2.79img/s]
#
#
# Processing Images:   2%|▏         | 520/25000 [03:04<2:25:39,  2.80img/s]
#
#
# Processing Images:   2%|▏         | 524/25000 [03:05<2:26:09,  2.79img/s]
#
#
# Processing Images:   2%|▏         | 528/25000 [03:07<2:26:58,  2.78img/s]
#
#
# Processing Images:   2%|▏         | 532/25000 [03:08<2:26:58,  2.77img/s]
#
#
# Processing Images:   2%|▏         | 536/25000 [03:10<2:26:16,  2.79img/s]
#
#
# Processing Images:   2%|▏         | 540/25000 [03:11<2:25:28,  2.80img/s]
#
#
# Processing Images:   2%|▏         | 544/25000 [03:13<2:25:00,  2.81img/s]
#
#
# Processing Images:   2%|▏         | 548/25000 [03:14<2:24:47,  2.81img/s]
#
#
# Processing Images:   2%|▏         | 552/25000 [03:15<2:24:55,  2.81img/s]
#
#
# Processing Images:   2%|▏         | 556/25000 [03:17<2:25:17,  2.80img/s]
#
#
# Processing Images:   2%|▏         | 560/25000 [03:18<2:25:28,  2.80img/s]
#
#
# Processing Images:   2%|▏         | 564/25000 [03:20<2:25:02,  2.81img/s]
#
#
# Processing Images:   2%|▏         | 568/25000 [03:21<2:24:03,  2.83img/s]
#
#
# Processing Images:   2%|▏         | 572/25000 [03:23<2:23:54,  2.83img/s]
#
#
# Processing Images:   2%|▏         | 576/25000 [03:24<2:23:39,  2.83img/s]
#
#
# Processing Images:   2%|▏         | 580/25000 [03:25<2:23:50,  2.83img/s]
#
#
# Processing Images:   2%|▏         | 584/25000 [03:27<2:25:03,  2.81img/s]
#
#
# Processing Images:   2%|▏         | 588/25000 [03:28<2:24:17,  2.82img/s]
#
#
# Processing Images:   2%|▏         | 592/25000 [03:30<2:23:32,  2.83img/s]
#
#
# Processing Images:   2%|▏         | 596/25000 [03:31<2:23:26,  2.84img/s]
#
#
# Processing Images:   2%|▏         | 600/25000 [03:32<2:23:05,  2.84img/s]
#
#
# Processing Images:   2%|▏         | 604/25000 [03:34<2:22:47,  2.85img/s]
#
#
# Processing Images:   2%|▏         | 608/25000 [03:35<2:23:03,  2.84img/s]
#
#
# Processing Images:   2%|▏         | 612/25000 [03:37<2:23:47,  2.83img/s]
#
#
# Processing Images:   2%|▏         | 616/25000 [03:38<2:23:38,  2.83img/s]
#
#
# Processing Images:   2%|▏         | 620/25000 [03:39<2:23:50,  2.82img/s]
#
#
# Processing Images:   2%|▏         | 624/25000 [03:41<2:24:01,  2.82img/s]
#
#
# Processing Images:   3%|▎         | 628/25000 [03:42<2:23:03,  2.84img/s]
#
#
# Processing Images:   3%|▎         | 632/25000 [03:44<2:23:09,  2.84img/s]
#
#
# Processing Images:   3%|▎         | 636/25000 [03:45<2:22:36,  2.85img/s]
#
#
# Processing Images:   3%|▎         | 640/25000 [03:47<2:23:23,  2.83img/s]
#
#
# Processing Images:   3%|▎         | 644/25000 [03:48<2:23:04,  2.84img/s]
#
#
# Processing Images:   3%|▎         | 648/25000 [03:49<2:23:01,  2.84img/s]
#
#
# Processing Images:   3%|▎         | 652/25000 [03:51<2:23:01,  2.84img/s]
#
#
# Processing Images:   3%|▎         | 656/25000 [03:52<2:21:57,  2.86img/s]
#
#
# Processing Images:   3%|▎         | 660/25000 [03:54<2:21:49,  2.86img/s]
#
#
# Processing Images:   3%|▎         | 664/25000 [03:55<2:22:34,  2.84img/s]
#
#
# Processing Images:   3%|▎         | 668/25000 [03:56<2:23:50,  2.82img/s]
#
#
# Processing Images:   3%|▎         | 672/25000 [03:58<2:23:55,  2.82img/s]
#
#
# Processing Images:   3%|▎         | 676/25000 [03:59<2:23:39,  2.82img/s]
#
#
# Processing Images:   3%|▎         | 680/25000 [04:01<2:23:37,  2.82img/s]
#
#
# Processing Images:   3%|▎         | 684/25000 [04:02<2:23:09,  2.83img/s]
#
#
# Processing Images:   3%|▎         | 688/25000 [04:03<2:23:31,  2.82img/s]
#
#
# Processing Images:   3%|▎         | 692/25000 [04:05<2:23:32,  2.82img/s]
#
#
# Processing Images:   3%|▎         | 696/25000 [04:06<2:24:17,  2.81img/s]
#
#
# Processing Images:   3%|▎         | 700/25000 [04:08<2:24:09,  2.81img/s]
#
#
# Processing Images:   3%|▎         | 704/25000 [04:09<2:23:40,  2.82img/s]
#
#
# Processing Images:   3%|▎         | 708/25000 [04:11<2:23:44,  2.82img/s]
#
#
# Processing Images:   3%|▎         | 712/25000 [04:12<2:22:51,  2.83img/s]
#
#
# Processing Images:   3%|▎         | 716/25000 [04:13<2:22:03,  2.85img/s]
#
#
# Processing Images:   3%|▎         | 720/25000 [04:15<2:21:29,  2.86img/s]
#
#
# Processing Images:   3%|▎         | 724/25000 [04:16<2:22:36,  2.84img/s]
#
#
# Processing Images:   3%|▎         | 728/25000 [04:18<2:24:04,  2.81img/s]
#
#
# Processing Images:   3%|▎         | 732/25000 [04:19<2:23:38,  2.82img/s]
#
#
# Processing Images:   3%|▎         | 736/25000 [04:20<2:23:33,  2.82img/s]
#
#
# Processing Images:   3%|▎         | 740/25000 [04:22<2:23:26,  2.82img/s]
#
#
# Processing Images:   3%|▎         | 744/25000 [04:23<2:23:04,  2.83img/s]
#
#
# Processing Images:   3%|▎         | 748/25000 [04:25<2:22:39,  2.83img/s]
#
#
# Processing Images:   3%|▎         | 752/25000 [04:26<2:22:01,  2.85img/s]
#
#
# Processing Images:   3%|▎         | 756/25000 [04:28<2:23:24,  2.82img/s]
#
#
# Processing Images:   3%|▎         | 760/25000 [04:29<2:24:37,  2.79img/s]
#
#
# Processing Images:   3%|▎         | 764/25000 [04:30<2:24:09,  2.80img/s]
#
#
# Processing Images:   3%|▎         | 768/25000 [04:32<2:24:25,  2.80img/s]
#
#
# Processing Images:   3%|▎         | 772/25000 [04:33<2:24:04,  2.80img/s]
#
#
# Processing Images:   3%|▎         | 776/25000 [04:35<2:23:45,  2.81img/s]
#
#
# Processing Images:   3%|▎         | 780/25000 [04:36<2:24:14,  2.80img/s]
#
#
# Processing Images:   3%|▎         | 784/25000 [04:38<2:25:13,  2.78img/s]
#
#
# Processing Images:   3%|▎         | 788/25000 [04:39<2:25:14,  2.78img/s]
#
#
# Processing Images:   3%|▎         | 792/25000 [04:40<2:24:28,  2.79img/s]
#
#
# Processing Images:   3%|▎         | 796/25000 [04:42<2:25:30,  2.77img/s]
#
#
# Processing Images:   3%|▎         | 800/25000 [04:43<2:25:35,  2.77img/s]
#
#
# Processing Images:   3%|▎         | 804/25000 [04:45<2:24:37,  2.79img/s]
#
#
# Processing Images:   3%|▎         | 808/25000 [04:46<2:25:32,  2.77img/s]
#
#
# Processing Images:   3%|▎         | 812/25000 [04:48<2:26:34,  2.75img/s]
#
#
# Processing Images:   3%|▎         | 816/25000 [04:49<2:26:38,  2.75img/s]
#
#
# Processing Images:   3%|▎         | 820/25000 [04:51<2:25:50,  2.76img/s]
#
#
# Processing Images:   3%|▎         | 824/25000 [04:52<2:25:17,  2.77img/s]
#
#
# Processing Images:   3%|▎         | 828/25000 [04:53<2:24:56,  2.78img/s]
#
#
# Processing Images:   3%|▎         | 832/25000 [04:55<2:24:45,  2.78img/s]
#
#
# Processing Images:   3%|▎         | 836/25000 [04:56<2:25:26,  2.77img/s]
#
#
# Processing Images:   3%|▎         | 840/25000 [04:58<2:24:06,  2.79img/s]
#
#
# Processing Images:   3%|▎         | 844/25000 [04:59<2:24:18,  2.79img/s]
#
#
# Processing Images:   3%|▎         | 848/25000 [05:01<2:23:48,  2.80img/s]
#
#
# Processing Images:   3%|▎         | 852/25000 [05:02<2:23:08,  2.81img/s]
#
#
# Processing Images:   3%|▎         | 856/25000 [05:03<2:22:18,  2.83img/s]
#
#
# Processing Images:   3%|▎         | 860/25000 [05:05<2:22:14,  2.83img/s]
#
#
# Processing Images:   3%|▎         | 864/25000 [05:06<2:22:45,  2.82img/s]
#
#
# Processing Images:   3%|▎         | 868/25000 [05:08<2:23:31,  2.80img/s]
#
#
# Processing Images:   3%|▎         | 872/25000 [05:09<2:23:13,  2.81img/s]
#
#
# Processing Images:   4%|▎         | 876/25000 [05:11<2:22:39,  2.82img/s]
#
#
# Processing Images:   4%|▎         | 880/25000 [05:12<2:22:29,  2.82img/s]
#
#
# Processing Images:   4%|▎         | 884/25000 [05:13<2:22:05,  2.83img/s]
#
#
# Processing Images:   4%|▎         | 888/25000 [05:15<2:22:03,  2.83img/s]
#
#
# Processing Images:   4%|▎         | 892/25000 [05:16<2:22:20,  2.82img/s]
#
#
# Processing Images:   4%|▎         | 896/25000 [05:18<2:24:31,  2.78img/s]
#
#
# Processing Images:   4%|▎         | 900/25000 [05:19<2:23:57,  2.79img/s]
#
#
# Processing Images:   4%|▎         | 904/25000 [05:21<2:22:58,  2.81img/s]
#
#
# Processing Images:   4%|▎         | 908/25000 [05:22<2:22:49,  2.81img/s]
#
#
# Processing Images:   4%|▎         | 912/25000 [05:23<2:22:05,  2.83img/s]
#
#
# Processing Images:   4%|▎         | 916/25000 [05:25<2:21:58,  2.83img/s]
#
#
# Processing Images:   4%|▎         | 920/25000 [05:26<2:21:27,  2.84img/s]
#
#
# Processing Images:   4%|▎         | 924/25000 [05:28<2:21:45,  2.83img/s]
#
#
# Processing Images:   4%|▎         | 928/25000 [05:29<2:22:26,  2.82img/s]
#
#
# Processing Images:   4%|▎         | 932/25000 [05:30<2:22:32,  2.81img/s]
#
#
# Processing Images:   4%|▎         | 936/25000 [05:32<2:22:05,  2.82img/s]
#
#
# Processing Images:   4%|▍         | 940/25000 [05:33<2:21:38,  2.83img/s]
#
#
# Processing Images:   4%|▍         | 944/25000 [05:35<2:20:59,  2.84img/s]
#
#
# Processing Images:   4%|▍         | 948/25000 [05:36<2:20:31,  2.85img/s]
#
#
# Processing Images:   4%|▍         | 952/25000 [05:38<2:23:08,  2.80img/s]
#
#
# Processing Images:   4%|▍         | 956/25000 [05:39<2:22:48,  2.81img/s]
#
#
# Processing Images:   4%|▍         | 960/25000 [05:40<2:21:45,  2.83img/s]
#
#
# Processing Images:   4%|▍         | 964/25000 [05:42<2:21:19,  2.83img/s]
#
#
# Processing Images:   4%|▍         | 968/25000 [05:43<2:21:30,  2.83img/s]
#
#
# Processing Images:   4%|▍         | 972/25000 [05:45<2:21:07,  2.84img/s]
#
#
# Processing Images:   4%|▍         | 976/25000 [05:46<2:20:22,  2.85img/s]
#
#
# Processing Images:   4%|▍         | 980/25000 [05:47<2:22:15,  2.81img/s]
#
#
# Processing Images:   4%|▍         | 984/25000 [05:49<2:22:18,  2.81img/s]
#
#
# Processing Images:   4%|▍         | 988/25000 [05:50<2:22:23,  2.81img/s]
#
#
# Processing Images:   4%|▍         | 992/25000 [05:52<2:21:35,  2.83img/s]
#
#
# Processing Images:   4%|▍         | 996/25000 [05:53<2:21:41,  2.82img/s]
#
#
# Processing Images:   4%|▍         | 1000/25000 [05:54<2:21:02,  2.84img/s]
#
#
# Processing Images:   4%|▍         | 1004/25000 [05:56<2:21:47,  2.82img/s]
#
#
# Processing Images:   4%|▍         | 1008/25000 [05:57<2:23:55,  2.78img/s]
#
#
# Processing Images:   4%|▍         | 1012/25000 [05:59<2:23:20,  2.79img/s]
#
#
# Processing Images:   4%|▍         | 1016/25000 [06:00<2:22:54,  2.80img/s]
#
#
# Processing Images:   4%|▍         | 1020/25000 [06:02<2:22:44,  2.80img/s]
#
#
# Processing Images:   4%|▍         | 1024/25000 [06:03<2:22:05,  2.81img/s]
#
#
# Processing Images:   4%|▍         | 1028/25000 [06:04<2:21:30,  2.82img/s]
#
#
# Processing Images:   4%|▍         | 1032/25000 [06:06<2:21:26,  2.82img/s]
#
#
# Processing Images:   4%|▍         | 1036/25000 [06:07<2:24:03,  2.77img/s]
#
#
# Processing Images:   4%|▍         | 1040/25000 [06:09<2:23:26,  2.78img/s]
#
#
# Processing Images:   4%|▍         | 1044/25000 [06:10<2:23:25,  2.78img/s]
#
#
# Processing Images:   4%|▍         | 1048/25000 [06:12<2:22:18,  2.81img/s]
#
#
# Processing Images:   4%|▍         | 1052/25000 [06:13<2:22:16,  2.81img/s]
#
#
# Processing Images:   4%|▍         | 1056/25000 [06:14<2:22:06,  2.81img/s]
#
#
# Processing Images:   4%|▍         | 1060/25000 [06:16<2:22:02,  2.81img/s]
#
#
# Processing Images:   4%|▍         | 1064/25000 [06:17<2:23:05,  2.79img/s]
#
#
# Processing Images:   4%|▍         | 1068/25000 [06:19<2:22:15,  2.80img/s]
#
#
# Processing Images:   4%|▍         | 1072/25000 [06:20<2:21:38,  2.82img/s]
#
#
# Processing Images:   4%|▍         | 1076/25000 [06:22<2:22:05,  2.81img/s]
#
#
# Processing Images:   4%|▍         | 1080/25000 [06:23<2:21:20,  2.82img/s]
#
#
# Processing Images:   4%|▍         | 1084/25000 [06:24<2:20:29,  2.84img/s]
#
#
# Processing Images:   4%|▍         | 1088/25000 [06:26<2:21:30,  2.82img/s]
#
#
# Processing Images:   4%|▍         | 1092/25000 [06:27<2:23:08,  2.78img/s]
#
#
# Processing Images:   4%|▍         | 1096/25000 [06:29<2:23:10,  2.78img/s]
#
#
# Processing Images:   4%|▍         | 1100/25000 [06:30<2:23:10,  2.78img/s]
#
#
# Processing Images:   4%|▍         | 1104/25000 [06:32<2:23:24,  2.78img/s]
#
#
# Processing Images:   4%|▍         | 1108/25000 [06:33<2:23:16,  2.78img/s]
#
#
# Processing Images:   4%|▍         | 1112/25000 [06:35<2:23:17,  2.78img/s]
#
#
# Processing Images:   4%|▍         | 1116/25000 [06:36<2:22:35,  2.79img/s]
#
#
# Processing Images:   4%|▍         | 1120/25000 [06:37<2:24:08,  2.76img/s]
#
#
# Processing Images:   4%|▍         | 1124/25000 [06:39<2:23:34,  2.77img/s]
#
#
# Processing Images:   5%|▍         | 1128/25000 [06:40<2:23:39,  2.77img/s]
#
#
# Processing Images:   5%|▍         | 1132/25000 [06:42<2:23:16,  2.78img/s]
#
#
# Processing Images:   5%|▍         | 1136/25000 [06:43<2:23:26,  2.77img/s]
#
#
# Processing Images:   5%|▍         | 1140/25000 [06:45<2:23:10,  2.78img/s]
#
#
# Processing Images:   5%|▍         | 1144/25000 [06:46<2:22:23,  2.79img/s]
#
#
# Processing Images:   5%|▍         | 1148/25000 [06:48<2:24:40,  2.75img/s]
#
#
# Processing Images:   5%|▍         | 1152/25000 [06:49<2:24:47,  2.75img/s]
#
#
# Processing Images:   5%|▍         | 1156/25000 [06:50<2:23:21,  2.77img/s]
#
#
# Processing Images:   5%|▍         | 1160/25000 [06:52<2:23:50,  2.76img/s]
#
#
# Processing Images:   5%|▍         | 1164/25000 [06:53<2:23:27,  2.77img/s]
#
#
# Processing Images:   5%|▍         | 1168/25000 [06:55<2:22:38,  2.78img/s]
#
#
# Processing Images:   5%|▍         | 1172/25000 [06:56<2:22:09,  2.79img/s]
#
#
# Processing Images:   5%|▍         | 1176/25000 [06:58<2:22:52,  2.78img/s]
#
#
# Processing Images:   5%|▍         | 1180/25000 [06:59<2:22:14,  2.79img/s]
#
#
# Processing Images:   5%|▍         | 1184/25000 [07:00<2:21:45,  2.80img/s]
#
#
# Processing Images:   5%|▍         | 1188/25000 [07:02<2:21:58,  2.80img/s]
#
#
# Processing Images:   5%|▍         | 1192/25000 [07:03<2:22:11,  2.79img/s]
#
#
# Processing Images:   5%|▍         | 1196/25000 [07:05<2:22:28,  2.78img/s]
#
#
# Processing Images:   5%|▍         | 1200/25000 [07:06<2:22:55,  2.78img/s]
#
#
# Processing Images:   5%|▍         | 1204/25000 [07:08<2:23:49,  2.76img/s]
#
#
# Processing Images:   5%|▍         | 1208/25000 [07:09<2:24:10,  2.75img/s]
#
#
# Processing Images:   5%|▍         | 1212/25000 [07:11<2:23:21,  2.77img/s]
#
#
# Processing Images:   5%|▍         | 1216/25000 [07:12<2:22:46,  2.78img/s]
#
#
# Processing Images:   5%|▍         | 1220/25000 [07:13<2:22:21,  2.78img/s]
#
#
# Processing Images:   5%|▍         | 1224/25000 [07:15<2:22:07,  2.79img/s]
#
#
# Processing Images:   5%|▍         | 1228/25000 [07:16<2:22:17,  2.78img/s]
#
#
# Processing Images:   5%|▍         | 1232/25000 [07:18<2:23:51,  2.75img/s]
#
#
# Processing Images:   5%|▍         | 1236/25000 [07:19<2:23:05,  2.77img/s]
#
#
# Processing Images:   5%|▍         | 1240/25000 [07:21<2:22:08,  2.79img/s]
#
#
# Processing Images:   5%|▍         | 1244/25000 [07:22<2:22:05,  2.79img/s]
#
#
# Processing Images:   5%|▍         | 1248/25000 [07:24<2:21:59,  2.79img/s]
#
#
# Processing Images:   5%|▌         | 1252/25000 [07:25<2:22:08,  2.78img/s]
#
#
# Processing Images:   5%|▌         | 1256/25000 [07:26<2:23:39,  2.75img/s]
#
#
# Processing Images:   5%|▌         | 1260/25000 [07:28<2:22:12,  2.78img/s]
#
#
# Processing Images:   5%|▌         | 1264/25000 [07:29<2:21:48,  2.79img/s]
#
#
# Processing Images:   5%|▌         | 1268/25000 [07:31<2:21:12,  2.80img/s]
#
#
# Processing Images:   5%|▌         | 1272/25000 [07:32<2:20:11,  2.82img/s]
#
#
# Processing Images:   5%|▌         | 1276/25000 [07:33<2:20:07,  2.82img/s]
#
#
# Processing Images:   5%|▌         | 1280/25000 [07:35<2:19:40,  2.83img/s]
#
#
# Processing Images:   5%|▌         | 1284/25000 [07:36<2:20:51,  2.81img/s]
#
#
# Processing Images:   5%|▌         | 1288/25000 [07:38<2:20:26,  2.81img/s]
#
#
# Processing Images:   5%|▌         | 1292/25000 [07:39<2:20:06,  2.82img/s]
#
#
# Processing Images:   5%|▌         | 1296/25000 [07:41<2:19:47,  2.83img/s]
#
#
# Processing Images:   5%|▌         | 1300/25000 [07:42<2:19:00,  2.84img/s]
#
#
# Processing Images:   5%|▌         | 1304/25000 [07:43<2:18:15,  2.86img/s]
#
#
# Processing Images:   5%|▌         | 1308/25000 [07:45<2:18:14,  2.86img/s]
#
#
# Processing Images:   5%|▌         | 1312/25000 [07:46<2:18:20,  2.85img/s]
#
#
# Processing Images:   5%|▌         | 1316/25000 [07:48<2:19:12,  2.84img/s]
#
#
# Processing Images:   5%|▌         | 1320/25000 [07:49<2:19:35,  2.83img/s]
#
#
# Processing Images:   5%|▌         | 1324/25000 [07:50<2:19:11,  2.84img/s]
#
#
# Processing Images:   5%|▌         | 1328/25000 [07:52<2:19:41,  2.82img/s]
#
#
# Processing Images:   5%|▌         | 1332/25000 [07:53<2:19:37,  2.83img/s]
#
#
# Processing Images:   5%|▌         | 1336/25000 [07:55<2:18:46,  2.84img/s]
#
#
# Processing Images:   5%|▌         | 1340/25000 [07:56<2:19:05,  2.84img/s]
#
#
# Processing Images:   5%|▌         | 1344/25000 [07:58<2:20:35,  2.80img/s]
#
#
# Processing Images:   5%|▌         | 1348/25000 [07:59<2:20:22,  2.81img/s]
#
#
# Processing Images:   5%|▌         | 1352/25000 [08:00<2:20:15,  2.81img/s]
#
#
# Processing Images:   5%|▌         | 1356/25000 [08:02<2:19:51,  2.82img/s]
#
#
# Processing Images:   5%|▌         | 1360/25000 [08:03<2:19:54,  2.82img/s]
#
#
# Processing Images:   5%|▌         | 1364/25000 [08:05<2:21:00,  2.79img/s]
#
#
# Processing Images:   5%|▌         | 1368/25000 [08:06<2:20:53,  2.80img/s]
#
#
# Processing Images:   5%|▌         | 1372/25000 [08:08<2:22:28,  2.76img/s]
#
#
# Processing Images:   6%|▌         | 1376/25000 [08:09<2:22:15,  2.77img/s]
#
#
# Processing Images:   6%|▌         | 1380/25000 [08:10<2:20:50,  2.80img/s]
#
#
# Processing Images:   6%|▌         | 1384/25000 [08:12<2:19:58,  2.81img/s]
#
#
# Processing Images:   6%|▌         | 1388/25000 [08:13<2:19:40,  2.82img/s]
#
#
# Processing Images:   6%|▌         | 1392/25000 [08:15<2:18:59,  2.83img/s]
#
#
# Processing Images:   6%|▌         | 1396/25000 [08:16<2:18:44,  2.84img/s]
#
#
# Processing Images:   6%|▌         | 1400/25000 [08:17<2:19:50,  2.81img/s]
#
#
# Processing Images:   6%|▌         | 1404/25000 [08:19<2:19:04,  2.83img/s]
#
#
# Processing Images:   6%|▌         | 1408/25000 [08:20<2:18:58,  2.83img/s]
#
#
# Processing Images:   6%|▌         | 1412/25000 [08:22<2:18:24,  2.84img/s]
#
#
# Processing Images:   6%|▌         | 1416/25000 [08:23<2:18:06,  2.85img/s]
#
#
# Processing Images:   6%|▌         | 1420/25000 [08:24<2:18:12,  2.84img/s]
#
#
# Processing Images:   6%|▌         | 1424/25000 [08:26<2:18:22,  2.84img/s]
#
#
# Processing Images:   6%|▌         | 1428/25000 [08:27<2:20:05,  2.80img/s]
#
#
# Processing Images:   6%|▌         | 1432/25000 [08:29<2:19:38,  2.81img/s]
#
#
# Processing Images:   6%|▌         | 1436/25000 [08:30<2:18:40,  2.83img/s]
#
#
# Processing Images:   6%|▌         | 1440/25000 [08:32<2:18:25,  2.84img/s]
#
#
# Processing Images:   6%|▌         | 1444/25000 [08:33<2:17:55,  2.85img/s]
#
#
# Processing Images:   6%|▌         | 1448/25000 [08:34<2:17:51,  2.85img/s]
#
#
# Processing Images:   6%|▌         | 1452/25000 [08:36<2:18:05,  2.84img/s]
#
#
# Processing Images:   6%|▌         | 1456/25000 [08:37<2:19:37,  2.81img/s]
#
#
# Processing Images:   6%|▌         | 1460/25000 [08:39<2:19:02,  2.82img/s]
#
#
# Processing Images:   6%|▌         | 1464/25000 [08:40<2:18:33,  2.83img/s]
#
#
# Processing Images:   6%|▌         | 1468/25000 [08:41<2:18:37,  2.83img/s]
#
#
# Processing Images:   6%|▌         | 1472/25000 [08:43<2:18:18,  2.84img/s]
#
#
# Processing Images:   6%|▌         | 1476/25000 [08:44<2:18:04,  2.84img/s]
#
#
# Processing Images:   6%|▌         | 1480/25000 [08:46<2:17:52,  2.84img/s]
#
#
# Processing Images:   6%|▌         | 1484/25000 [08:47<2:19:04,  2.82img/s]
#
#
# Processing Images:   6%|▌         | 1488/25000 [08:49<2:18:11,  2.84img/s]
#
#
# Processing Images:   6%|▌         | 1492/25000 [08:50<2:17:47,  2.84img/s]
#
#
# Processing Images:   6%|▌         | 1496/25000 [08:51<2:17:11,  2.86img/s]
#
#
# Processing Images:   6%|▌         | 1500/25000 [08:53<2:16:18,  2.87img/s]
#
#
# Processing Images:   6%|▌         | 1504/25000 [08:54<2:16:47,  2.86img/s]
#
#
# Processing Images:   6%|▌         | 1508/25000 [08:55<2:16:49,  2.86img/s]
#
#
# Processing Images:   6%|▌         | 1512/25000 [08:57<2:17:48,  2.84img/s]
#
#
# Processing Images:   6%|▌         | 1516/25000 [08:58<2:18:09,  2.83img/s]
#
#
# Processing Images:   6%|▌         | 1520/25000 [09:00<2:18:36,  2.82img/s]
#
#
# Processing Images:   6%|▌         | 1524/25000 [09:01<2:18:41,  2.82img/s]
#
#
# Processing Images:   6%|▌         | 1528/25000 [09:03<2:18:55,  2.82img/s]
#
#
# Processing Images:   6%|▌         | 1532/25000 [09:04<2:19:37,  2.80img/s]
#
#
# Processing Images:   6%|▌         | 1536/25000 [09:05<2:19:47,  2.80img/s]
#
#
# Processing Images:   6%|▌         | 1540/25000 [09:07<2:21:06,  2.77img/s]
#
#
# Processing Images:   6%|▌         | 1544/25000 [09:08<2:21:00,  2.77img/s]
#
#
# Processing Images:   6%|▌         | 1548/25000 [09:10<2:20:44,  2.78img/s]
#
#
# Processing Images:   6%|▌         | 1552/25000 [09:11<2:19:24,  2.80img/s]
#
#
# Processing Images:   6%|▌         | 1556/25000 [09:13<2:18:53,  2.81img/s]
#
#
# Processing Images:   6%|▌         | 1560/25000 [09:14<2:18:20,  2.82img/s]
#
#
# Processing Images:   6%|▋         | 1564/25000 [09:15<2:17:29,  2.84img/s]
#
#
# Processing Images:   6%|▋         | 1568/25000 [09:17<2:18:56,  2.81img/s]
#
#
# Processing Images:   6%|▋         | 1572/25000 [09:18<2:17:33,  2.84img/s]
#
#
# Processing Images:   6%|▋         | 1576/25000 [09:20<2:17:17,  2.84img/s]
#
#
# Processing Images:   6%|▋         | 1580/25000 [09:21<2:17:07,  2.85img/s]
#
#
# Processing Images:   6%|▋         | 1584/25000 [09:22<2:16:41,  2.85img/s]
#
#
# Processing Images:   6%|▋         | 1588/25000 [09:24<2:16:31,  2.86img/s]
#
#
# Processing Images:   6%|▋         | 1592/25000 [09:25<2:16:50,  2.85img/s]
#
#
# Processing Images:   6%|▋         | 1596/25000 [09:27<2:18:37,  2.81img/s]
#
#
# Processing Images:   6%|▋         | 1600/25000 [09:28<2:17:51,  2.83img/s]
#
#
# Processing Images:   6%|▋         | 1604/25000 [09:30<2:17:21,  2.84img/s]
#
#
# Processing Images:   6%|▋         | 1608/25000 [09:31<2:17:21,  2.84img/s]
#
#
# Processing Images:   6%|▋         | 1612/25000 [09:32<2:16:46,  2.85img/s]
#
#
# Processing Images:   6%|▋         | 1616/25000 [09:34<2:16:40,  2.85img/s]
#
#
# Processing Images:   6%|▋         | 1620/25000 [09:35<2:16:52,  2.85img/s]
#
#
# Processing Images:   6%|▋         | 1624/25000 [09:37<2:17:53,  2.83img/s]
#
#
# Processing Images:   7%|▋         | 1628/25000 [09:38<2:17:49,  2.83img/s]
#
#
# Processing Images:   7%|▋         | 1632/25000 [09:39<2:16:41,  2.85img/s]
#
#
# Processing Images:   7%|▋         | 1636/25000 [09:41<2:16:22,  2.86img/s]
#
#
# Processing Images:   7%|▋         | 1640/25000 [09:42<2:16:31,  2.85img/s]
#
#
# Processing Images:   7%|▋         | 1644/25000 [09:44<2:15:50,  2.87img/s]
#
#
# Processing Images:   7%|▋         | 1648/25000 [09:45<2:16:04,  2.86img/s]
#
#
# Processing Images:   7%|▋         | 1652/25000 [09:46<2:17:53,  2.82img/s]
#
#
# Processing Images:   7%|▋         | 1656/25000 [09:48<2:16:57,  2.84img/s]
#
#
# Processing Images:   7%|▋         | 1660/25000 [09:49<2:16:02,  2.86img/s]
#
#
# Processing Images:   7%|▋         | 1664/25000 [09:51<2:16:06,  2.86img/s]
#
#
# Processing Images:   7%|▋         | 1668/25000 [09:52<2:16:20,  2.85img/s]
#
#
# Processing Images:   7%|▋         | 1672/25000 [09:53<2:15:58,  2.86img/s]
#
#
# Processing Images:   7%|▋         | 1676/25000 [09:55<2:15:43,  2.86img/s]
#
#
# Processing Images:   7%|▋         | 1680/25000 [09:56<2:16:35,  2.85img/s]
#
#
# Processing Images:   7%|▋         | 1684/25000 [09:58<2:17:50,  2.82img/s]
#
#
# Processing Images:   7%|▋         | 1688/25000 [09:59<2:17:32,  2.82img/s]
#
#
# Processing Images:   7%|▋         | 1692/25000 [10:00<2:16:56,  2.84img/s]
#
#
# Processing Images:   7%|▋         | 1696/25000 [10:02<2:17:01,  2.83img/s]
#
#
# Processing Images:   7%|▋         | 1700/25000 [10:03<2:17:26,  2.83img/s]
#
#
# Processing Images:   7%|▋         | 1704/25000 [10:05<2:17:04,  2.83img/s]
#
#
# Processing Images:   7%|▋         | 1708/25000 [10:06<2:16:21,  2.85img/s]
#
#
# Processing Images:   7%|▋         | 1712/25000 [10:08<2:18:03,  2.81img/s]
#
#
# Processing Images:   7%|▋         | 1716/25000 [10:09<2:17:14,  2.83img/s]
#
#
# Processing Images:   7%|▋         | 1720/25000 [10:10<2:17:03,  2.83img/s]
#
#
# Processing Images:   7%|▋         | 1724/25000 [10:12<2:16:41,  2.84img/s]
#
#
# Processing Images:   7%|▋         | 1728/25000 [10:13<2:16:59,  2.83img/s]
#
#
# Processing Images:   7%|▋         | 1732/25000 [10:15<2:17:42,  2.82img/s]
#
#
# Processing Images:   7%|▋         | 1736/25000 [10:16<2:17:51,  2.81img/s]
#
#
# Processing Images:   7%|▋         | 1740/25000 [10:18<2:19:26,  2.78img/s]
#
#
# Processing Images:   7%|▋         | 1744/25000 [10:19<2:19:05,  2.79img/s]
#
#
# Processing Images:   7%|▋         | 1748/25000 [10:20<2:18:47,  2.79img/s]
#
#
# Processing Images:   7%|▋         | 1752/25000 [10:22<2:18:46,  2.79img/s]
#
#
# Processing Images:   7%|▋         | 1756/25000 [10:23<2:18:50,  2.79img/s]
#
#
# Processing Images:   7%|▋         | 1760/25000 [10:25<2:18:26,  2.80img/s]
#
#
# Processing Images:   7%|▋         | 1764/25000 [10:26<2:16:56,  2.83img/s]
#
#
# Processing Images:   7%|▋         | 1768/25000 [10:28<2:19:10,  2.78img/s]
#
#
# Processing Images:   7%|▋         | 1772/25000 [10:29<2:18:56,  2.79img/s]
#
#
# Processing Images:   7%|▋         | 1776/25000 [10:30<2:18:40,  2.79img/s]
#
#
# Processing Images:   7%|▋         | 1780/25000 [10:32<2:18:10,  2.80img/s]
#
#
# Processing Images:   7%|▋         | 1784/25000 [10:33<2:17:54,  2.81img/s]
#
#
# Processing Images:   7%|▋         | 1788/25000 [10:35<2:16:59,  2.82img/s]
#
#
# Processing Images:   7%|▋         | 1792/25000 [10:36<2:16:54,  2.83img/s]
#
#
# Processing Images:   7%|▋         | 1796/25000 [10:37<2:17:50,  2.81img/s]
#
#
# Processing Images:   7%|▋         | 1800/25000 [10:39<2:17:52,  2.80img/s]
#
#
# Processing Images:   7%|▋         | 1804/25000 [10:40<2:17:32,  2.81img/s]
#
#
# Processing Images:   7%|▋         | 1808/25000 [10:42<2:16:40,  2.83img/s]
#
#
# Processing Images:   7%|▋         | 1812/25000 [10:43<2:16:16,  2.84img/s]
#
#
# Processing Images:   7%|▋         | 1816/25000 [10:45<2:16:38,  2.83img/s]
#
#
# Processing Images:   7%|▋         | 1820/25000 [10:46<2:17:27,  2.81img/s]
#
#
# Processing Images:   7%|▋         | 1824/25000 [10:47<2:19:03,  2.78img/s]
#
#
# Processing Images:   7%|▋         | 1828/25000 [10:49<2:18:53,  2.78img/s]
#
#
# Processing Images:   7%|▋         | 1832/25000 [10:50<2:18:03,  2.80img/s]
#
#
# Processing Images:   7%|▋         | 1836/25000 [10:52<2:17:37,  2.81img/s]
#
#
# Processing Images:   7%|▋         | 1840/25000 [10:53<2:17:34,  2.81img/s]
#
#
# Processing Images:   7%|▋         | 1844/25000 [10:55<2:17:07,  2.81img/s]
#
#
# Processing Images:   7%|▋         | 1848/25000 [10:56<2:17:33,  2.81img/s]
#
#
# Processing Images:   7%|▋         | 1852/25000 [10:57<2:17:58,  2.80img/s]
#
#
# Processing Images:   7%|▋         | 1856/25000 [10:59<2:17:22,  2.81img/s]
#
#
# Processing Images:   7%|▋         | 1860/25000 [11:00<2:17:30,  2.80img/s]
#
#
# Processing Images:   7%|▋         | 1864/25000 [11:02<2:17:37,  2.80img/s]
#
#
# Processing Images:   7%|▋         | 1868/25000 [11:03<2:17:27,  2.80img/s]
#
#
# Processing Images:   7%|▋         | 1872/25000 [11:05<2:17:47,  2.80img/s]
#
#
# Processing Images:   8%|▊         | 1876/25000 [11:06<2:17:42,  2.80img/s]
#
#
# Processing Images:   8%|▊         | 1880/25000 [11:08<2:19:21,  2.77img/s]
#
#
# Processing Images:   8%|▊         | 1884/25000 [11:09<2:18:35,  2.78img/s]
#
#
# Processing Images:   8%|▊         | 1888/25000 [11:10<2:17:57,  2.79img/s]
#
#
# Processing Images:   8%|▊         | 1892/25000 [11:12<2:17:59,  2.79img/s]
#
#
# Processing Images:   8%|▊         | 1896/25000 [11:13<2:17:41,  2.80img/s]
#
#
# Processing Images:   8%|▊         | 1900/25000 [11:15<2:17:59,  2.79img/s]
#
#
# Processing Images:   8%|▊         | 1904/25000 [11:16<2:18:06,  2.79img/s]
#
#
# Processing Images:   8%|▊         | 1908/25000 [11:18<2:18:43,  2.77img/s]
#
#
# Processing Images:   8%|▊         | 1912/25000 [11:19<2:18:31,  2.78img/s]
#
#
# Processing Images:   8%|▊         | 1916/25000 [11:20<2:19:08,  2.76img/s]
#
#
# Processing Images:   8%|▊         | 1920/25000 [11:22<2:18:40,  2.77img/s]
#
#
# Processing Images:   8%|▊         | 1924/25000 [11:23<2:18:23,  2.78img/s]
#
#
# Processing Images:   8%|▊         | 1928/25000 [11:25<2:17:19,  2.80img/s]
#
#
# Processing Images:   8%|▊         | 1932/25000 [11:26<2:17:54,  2.79img/s]
#
#
# Processing Images:   8%|▊         | 1936/25000 [11:28<2:18:46,  2.77img/s]
#
#
# Processing Images:   8%|▊         | 1940/25000 [11:29<2:18:15,  2.78img/s]
#
#
# Processing Images:   8%|▊         | 1944/25000 [11:30<2:17:51,  2.79img/s]
#
#
# Processing Images:   8%|▊         | 1948/25000 [11:32<2:17:37,  2.79img/s]
#
#
# Processing Images:   8%|▊         | 1952/25000 [11:33<2:17:36,  2.79img/s]
#
#
# Processing Images:   8%|▊         | 1956/25000 [11:35<2:17:12,  2.80img/s]
#
#
# Processing Images:   8%|▊         | 1960/25000 [11:36<2:17:30,  2.79img/s]
#
#
# Processing Images:   8%|▊         | 1964/25000 [11:38<2:18:37,  2.77img/s]
#
#
# Processing Images:   8%|▊         | 1968/25000 [11:39<2:18:03,  2.78img/s]
#
#
# Processing Images:   8%|▊         | 1972/25000 [11:41<2:17:54,  2.78img/s]
#
#
# Processing Images:   8%|▊         | 1976/25000 [11:42<2:17:13,  2.80img/s]
#
#
# Processing Images:   8%|▊         | 1980/25000 [11:43<2:16:25,  2.81img/s]
#
#
# Processing Images:   8%|▊         | 1984/25000 [11:45<2:15:19,  2.83img/s]
#
#
# Processing Images:   8%|▊         | 1988/25000 [11:46<2:15:49,  2.82img/s]
#
#
# Processing Images:   8%|▊         | 1992/25000 [11:48<2:16:45,  2.80img/s]
#
#
# Processing Images:   8%|▊         | 1996/25000 [11:49<2:16:01,  2.82img/s]
#
#
# Processing Images:   8%|▊         | 2000/25000 [11:50<2:15:35,  2.83img/s]
#
#
# Processing Images:   8%|▊         | 2004/25000 [11:52<2:15:12,  2.83img/s]
#
#
# Processing Images:   8%|▊         | 2008/25000 [11:53<2:15:18,  2.83img/s]
#
#
# Processing Images:   8%|▊         | 2012/25000 [11:55<2:14:51,  2.84img/s]
#
#
# Processing Images:   8%|▊         | 2016/25000 [11:56<2:14:43,  2.84img/s]
#
#
# Processing Images:   8%|▊         | 2020/25000 [11:57<2:15:35,  2.82img/s]
#
#
# Processing Images:   8%|▊         | 2024/25000 [11:59<2:14:34,  2.85img/s]
#
#
# Processing Images:   8%|▊         | 2028/25000 [12:00<2:14:22,  2.85img/s]
#
#
# Processing Images:   8%|▊         | 2032/25000 [12:02<2:14:13,  2.85img/s]
#
#
# Processing Images:   8%|▊         | 2036/25000 [12:03<2:14:30,  2.85img/s]
#
#
# Processing Images:   8%|▊         | 2040/25000 [12:04<2:14:49,  2.84img/s]
#
#
# Processing Images:   8%|▊         | 2044/25000 [12:06<2:14:37,  2.84img/s]
#
#
# Processing Images:   8%|▊         | 2048/25000 [12:07<2:16:30,  2.80img/s]
#
#
# Processing Images:   8%|▊         | 2052/25000 [12:09<2:16:06,  2.81img/s]
#
#
# Processing Images:   8%|▊         | 2056/25000 [12:10<2:15:03,  2.83img/s]
#
#
# Processing Images:   8%|▊         | 2060/25000 [12:12<2:14:09,  2.85img/s]
#
#
# Processing Images:   8%|▊         | 2064/25000 [12:13<2:13:40,  2.86img/s]
#
#
# Processing Images:   8%|▊         | 2068/25000 [12:14<2:14:09,  2.85img/s]
#
#
# Processing Images:   8%|▊         | 2072/25000 [12:16<2:13:54,  2.85img/s]
#
#
# Processing Images:   8%|▊         | 2076/25000 [12:17<2:15:55,  2.81img/s]
#
#
# Processing Images:   8%|▊         | 2080/25000 [12:19<2:15:40,  2.82img/s]
#
#
# Processing Images:   8%|▊         | 2084/25000 [12:20<2:15:37,  2.82img/s]
#
#
# Processing Images:   8%|▊         | 2088/25000 [12:21<2:14:24,  2.84img/s]
#
#
# Processing Images:   8%|▊         | 2092/25000 [12:23<2:14:11,  2.85img/s]
#
#
# Processing Images:   8%|▊         | 2096/25000 [12:24<2:14:04,  2.85img/s]
#
#
# Processing Images:   8%|▊         | 2100/25000 [12:26<2:14:16,  2.84img/s]
#
#
# Processing Images:   8%|▊         | 2104/25000 [12:27<2:16:34,  2.79img/s]
#
#
# Processing Images:   8%|▊         | 2108/25000 [12:29<2:16:57,  2.79img/s]
#
#
# Processing Images:   8%|▊         | 2112/25000 [12:30<2:16:28,  2.80img/s]
#
#
# Processing Images:   8%|▊         | 2116/25000 [12:31<2:16:03,  2.80img/s]
#
#
# Processing Images:   8%|▊         | 2120/25000 [12:33<2:16:03,  2.80img/s]
#
#
# Processing Images:   8%|▊         | 2124/25000 [12:34<2:16:06,  2.80img/s]
#
#
# Processing Images:   9%|▊         | 2128/25000 [12:36<2:15:34,  2.81img/s]
#
#
# Processing Images:   9%|▊         | 2132/25000 [12:37<2:17:01,  2.78img/s]
#
#
# Processing Images:   9%|▊         | 2136/25000 [12:39<2:16:40,  2.79img/s]
#
#
# Processing Images:   9%|▊         | 2140/25000 [12:40<2:16:11,  2.80img/s]
#
#
# Processing Images:   9%|▊         | 2144/25000 [12:41<2:15:40,  2.81img/s]
#
#
# Processing Images:   9%|▊         | 2148/25000 [12:43<2:14:53,  2.82img/s]
#
#
# Processing Images:   9%|▊         | 2152/25000 [12:44<2:14:59,  2.82img/s]
#
#
# Processing Images:   9%|▊         | 2156/25000 [12:46<2:15:02,  2.82img/s]
#
#
# Processing Images:   9%|▊         | 2160/25000 [12:47<2:16:27,  2.79img/s]
#
#
# Processing Images:   9%|▊         | 2164/25000 [12:49<2:15:59,  2.80img/s]
#
#
# Processing Images:   9%|▊         | 2168/25000 [12:50<2:15:37,  2.81img/s]
#
#
# Processing Images:   9%|▊         | 2172/25000 [12:51<2:15:19,  2.81img/s]
#
#
# Processing Images:   9%|▊         | 2176/25000 [12:53<2:15:37,  2.80img/s]
#
#
# Processing Images:   9%|▊         | 2180/25000 [12:54<2:16:08,  2.79img/s]
#
#
# Processing Images:   9%|▊         | 2184/25000 [12:56<2:15:58,  2.80img/s]
#
#
# Processing Images:   9%|▉         | 2188/25000 [12:57<2:18:31,  2.74img/s]
#
#
# Processing Images:   9%|▉         | 2192/25000 [12:59<2:18:18,  2.75img/s]
#
#
# Processing Images:   9%|▉         | 2196/25000 [13:00<2:17:50,  2.76img/s]
#
#
# Processing Images:   9%|▉         | 2200/25000 [13:02<2:17:37,  2.76img/s]
#
#
# Processing Images:   9%|▉         | 2204/25000 [13:03<2:17:40,  2.76img/s]
#
#
# Processing Images:   9%|▉         | 2208/25000 [13:04<2:17:33,  2.76img/s]
#
#
# Processing Images:   9%|▉         | 2212/25000 [13:06<2:17:28,  2.76img/s]
#
#
# Processing Images:   9%|▉         | 2216/25000 [13:07<2:19:16,  2.73img/s]
#
#
# Processing Images:   9%|▉         | 2220/25000 [13:09<2:18:37,  2.74img/s]
#
#
# Processing Images:   9%|▉         | 2224/25000 [13:10<2:18:14,  2.75img/s]
#
#
# Processing Images:   9%|▉         | 2228/25000 [13:12<2:17:40,  2.76img/s]
#
#
# Processing Images:   9%|▉         | 2232/25000 [13:13<2:17:28,  2.76img/s]
#
#
# Processing Images:   9%|▉         | 2236/25000 [13:15<2:17:53,  2.75img/s]
#
#
# Processing Images:   9%|▉         | 2240/25000 [13:16<2:17:38,  2.76img/s]
#
#
# Processing Images:   9%|▉         | 2244/25000 [13:18<2:18:11,  2.74img/s]
#
#
# Processing Images:   9%|▉         | 2248/25000 [13:19<2:17:47,  2.75img/s]
#
#
# Processing Images:   9%|▉         | 2252/25000 [13:20<2:17:40,  2.75img/s]
#
#
# Processing Images:   9%|▉         | 2256/25000 [13:22<2:17:22,  2.76img/s]
#
#
# Processing Images:   9%|▉         | 2260/25000 [13:23<2:17:22,  2.76img/s]
#
#
# Processing Images:   9%|▉         | 2264/25000 [13:25<2:17:52,  2.75img/s]
#
#
# Processing Images:   9%|▉         | 2268/25000 [13:26<2:18:35,  2.73img/s]
#
#
# Processing Images:   9%|▉         | 2272/25000 [13:28<2:18:57,  2.73img/s]
#
#
# Processing Images:   9%|▉         | 2276/25000 [13:29<2:18:04,  2.74img/s]
#
#
# Processing Images:   9%|▉         | 2280/25000 [13:31<2:16:48,  2.77img/s]
#
#
# Processing Images:   9%|▉         | 2284/25000 [13:32<2:16:18,  2.78img/s]
#
#
# Processing Images:   9%|▉         | 2288/25000 [13:33<2:16:11,  2.78img/s]
#
#
# Processing Images:   9%|▉         | 2292/25000 [13:35<2:15:26,  2.79img/s]
#
#
# Processing Images:   9%|▉         | 2296/25000 [13:36<2:17:10,  2.76img/s]
#
#
# Processing Images:   9%|▉         | 2300/25000 [13:38<2:16:41,  2.77img/s]
#
#
# Processing Images:   9%|▉         | 2304/25000 [13:39<2:16:36,  2.77img/s]
#
#
# Processing Images:   9%|▉         | 2308/25000 [13:41<2:15:34,  2.79img/s]
#
#
# Processing Images:   9%|▉         | 2312/25000 [13:42<2:14:47,  2.81img/s]
#
#
# Processing Images:   9%|▉         | 2316/25000 [13:43<2:14:10,  2.82img/s]
#
#
# Processing Images:   9%|▉         | 2320/25000 [13:45<2:13:26,  2.83img/s]
#
#
# Processing Images:   9%|▉         | 2324/25000 [13:46<2:14:02,  2.82img/s]
#
#
# Processing Images:   9%|▉         | 2328/25000 [13:48<2:14:45,  2.80img/s]
#
#
# Processing Images:   9%|▉         | 2332/25000 [13:49<2:14:27,  2.81img/s]
#
#
# Processing Images:   9%|▉         | 2336/25000 [13:51<2:13:58,  2.82img/s]
#
#
# Processing Images:   9%|▉         | 2340/25000 [13:52<2:13:59,  2.82img/s]
#
#
# Processing Images:   9%|▉         | 2344/25000 [13:53<2:14:10,  2.81img/s]
#
#
# Processing Images:   9%|▉         | 2348/25000 [13:55<2:14:17,  2.81img/s]
#
#
# Processing Images:   9%|▉         | 2352/25000 [13:56<2:14:47,  2.80img/s]
#
#
# Processing Images:   9%|▉         | 2356/25000 [13:58<2:14:51,  2.80img/s]
#
#
# Processing Images:   9%|▉         | 2360/25000 [13:59<2:14:34,  2.80img/s]
#
#
# Processing Images:   9%|▉         | 2364/25000 [14:01<2:14:56,  2.80img/s]
#
#
# Processing Images:   9%|▉         | 2368/25000 [14:02<2:14:33,  2.80img/s]
#
#
# Processing Images:   9%|▉         | 2372/25000 [14:03<2:14:20,  2.81img/s]
#
#
# Processing Images:  10%|▉         | 2376/25000 [14:05<2:14:31,  2.80img/s]
#
#
# Processing Images:  10%|▉         | 2380/25000 [14:06<2:15:21,  2.79img/s]
#
#
# Processing Images:  10%|▉         | 2384/25000 [14:08<2:15:15,  2.79img/s]
#
#
# Processing Images:  10%|▉         | 2388/25000 [14:09<2:14:38,  2.80img/s]
#
#
# Processing Images:  10%|▉         | 2392/25000 [14:11<2:15:28,  2.78img/s]
#
#
# Processing Images:  10%|▉         | 2396/25000 [14:12<2:14:30,  2.80img/s]
#
#
# Processing Images:  10%|▉         | 2400/25000 [14:13<2:14:01,  2.81img/s]
#
#
# Processing Images:  10%|▉         | 2404/25000 [14:15<2:14:03,  2.81img/s]
#
#
# Processing Images:  10%|▉         | 2408/25000 [14:16<2:14:25,  2.80img/s]
#
#
# Processing Images:  10%|▉         | 2412/25000 [14:18<2:14:25,  2.80img/s]
#
#
# Processing Images:  10%|▉         | 2416/25000 [14:19<2:15:15,  2.78img/s]
#
#
# Processing Images:  10%|▉         | 2420/25000 [14:21<2:14:53,  2.79img/s]
#
#
# Processing Images:  10%|▉         | 2424/25000 [14:22<2:14:37,  2.80img/s]
#
#
# Processing Images:  10%|▉         | 2428/25000 [14:23<2:14:04,  2.81img/s]
#
#
# Processing Images:  10%|▉         | 2432/25000 [14:25<2:13:22,  2.82img/s]
#
#
# Processing Images:  10%|▉         | 2436/25000 [14:26<2:13:17,  2.82img/s]
#
#
# Processing Images:  10%|▉         | 2440/25000 [14:28<2:13:31,  2.82img/s]
#
#
# Processing Images:  10%|▉         | 2444/25000 [14:29<2:13:29,  2.82img/s]
#
#
# Processing Images:  10%|▉         | 2448/25000 [14:31<2:13:56,  2.81img/s]
#
#
# ...
#
#
# Processing Images:  97%|█████████▋| 24184/25000 [2:22:32<04:46,  2.85img/s]
#
#
# Processing Images:  97%|█████████▋| 24188/25000 [2:22:34<04:44,  2.85img/s]
#
#
# Processing Images:  97%|█████████▋| 24192/25000 [2:22:35<04:41,  2.87img/s]
#
#
# Processing Images:  97%|█████████▋| 24196/25000 [2:22:37<04:43,  2.84img/s]
#
#
# Processing Images:  97%|█████████▋| 24200/25000 [2:22:38<04:41,  2.84img/s]
#
#
# Processing Images:  97%|█████████▋| 24204/25000 [2:22:39<04:40,  2.84img/s]
#
#
# Processing Images:  97%|█████████▋| 24208/25000 [2:22:41<04:38,  2.85img/s]
#
#
# Processing Images:  97%|█████████▋| 24212/25000 [2:22:42<04:36,  2.85img/s]
#
#
# Processing Images:  97%|█████████▋| 24216/25000 [2:22:44<04:34,  2.86img/s]
#
#
# Processing Images:  97%|█████████▋| 24220/25000 [2:22:45<04:31,  2.87img/s]
#
#
# Processing Images:  97%|█████████▋| 24224/25000 [2:22:46<04:33,  2.84img/s]
#
#
# Processing Images:  97%|█████████▋| 24228/25000 [2:22:48<04:31,  2.85img/s]
#
#
# Processing Images:  97%|█████████▋| 24232/25000 [2:22:49<04:28,  2.86img/s]
#
#
# Processing Images:  97%|█████████▋| 24236/25000 [2:22:51<04:26,  2.86img/s]
#
#
# Processing Images:  97%|█████████▋| 24240/25000 [2:22:52<04:25,  2.87img/s]
#
#
# Processing Images:  97%|█████████▋| 24244/25000 [2:22:53<04:24,  2.86img/s]
#
#
# Processing Images:  97%|█████████▋| 24248/25000 [2:22:55<04:21,  2.87img/s]
#
#
# Processing Images:  97%|█████████▋| 24252/25000 [2:22:56<04:20,  2.88img/s]
#
#
# Processing Images:  97%|█████████▋| 24256/25000 [2:22:58<04:20,  2.85img/s]
#
#
# Processing Images:  97%|█████████▋| 24260/25000 [2:22:59<04:19,  2.85img/s]
#
#
# Processing Images:  97%|█████████▋| 24264/25000 [2:23:00<04:17,  2.86img/s]
#
#
# Processing Images:  97%|█████████▋| 24268/25000 [2:23:02<04:15,  2.86img/s]
#
#
# Processing Images:  97%|█████████▋| 24272/25000 [2:23:03<04:15,  2.85img/s]
#
#
# Processing Images:  97%|█████████▋| 24276/25000 [2:23:05<04:13,  2.85img/s]
#
#
# Processing Images:  97%|█████████▋| 24280/25000 [2:23:06<04:12,  2.85img/s]
#
#
# Processing Images:  97%|█████████▋| 24284/25000 [2:23:07<04:14,  2.81img/s]
#
#
# Processing Images:  97%|█████████▋| 24288/25000 [2:23:09<04:11,  2.83img/s]
#
#
# Processing Images:  97%|█████████▋| 24292/25000 [2:23:10<04:08,  2.85img/s]
#
#
# Processing Images:  97%|█████████▋| 24296/25000 [2:23:12<04:06,  2.86img/s]
#
#
# Processing Images:  97%|█████████▋| 24300/25000 [2:23:13<04:05,  2.85img/s]
#
#
# Processing Images:  97%|█████████▋| 24304/25000 [2:23:14<04:02,  2.87img/s]
#
#
# Processing Images:  97%|█████████▋| 24308/25000 [2:23:16<04:01,  2.87img/s]
#
#
# Processing Images:  97%|█████████▋| 24312/25000 [2:23:17<04:02,  2.84img/s]
#
#
# Processing Images:  97%|█████████▋| 24316/25000 [2:23:19<04:00,  2.85img/s]
#
#
# Processing Images:  97%|█████████▋| 24320/25000 [2:23:20<03:57,  2.86img/s]
#
#
# Processing Images:  97%|█████████▋| 24324/25000 [2:23:21<03:56,  2.86img/s]
#
#
# Processing Images:  97%|█████████▋| 24328/25000 [2:23:23<03:55,  2.85img/s]
#
#
# Processing Images:  97%|█████████▋| 24332/25000 [2:23:24<03:53,  2.86img/s]
#
#
# Processing Images:  97%|█████████▋| 24336/25000 [2:23:26<03:52,  2.85img/s]
#
#
# Processing Images:  97%|█████████▋| 24340/25000 [2:23:27<03:53,  2.83img/s]
#
#
# Processing Images:  97%|█████████▋| 24344/25000 [2:23:28<03:52,  2.83img/s]
#
#
# Processing Images:  97%|█████████▋| 24348/25000 [2:23:30<03:50,  2.83img/s]
#
#
# Processing Images:  97%|█████████▋| 24352/25000 [2:23:31<03:49,  2.83img/s]
#
#
# Processing Images:  97%|█████████▋| 24356/25000 [2:23:33<03:47,  2.83img/s]
#
#
# Processing Images:  97%|█████████▋| 24360/25000 [2:23:34<03:45,  2.83img/s]
#
#
# Processing Images:  97%|█████████▋| 24364/25000 [2:23:36<03:45,  2.82img/s]
#
#
# Processing Images:  97%|█████████▋| 24368/25000 [2:23:37<03:45,  2.80img/s]
#
#
# Processing Images:  97%|█████████▋| 24372/25000 [2:23:38<03:43,  2.81img/s]
#
#
# Processing Images:  98%|█████████▊| 24376/25000 [2:23:40<03:42,  2.80img/s]
#
#
# Processing Images:  98%|█████████▊| 24380/25000 [2:23:41<03:41,  2.80img/s]
#
#
# Processing Images:  98%|█████████▊| 24384/25000 [2:23:43<03:40,  2.79img/s]
#
#
# Processing Images:  98%|█████████▊| 24388/25000 [2:23:44<03:39,  2.79img/s]
#
#
# Processing Images:  98%|█████████▊| 24392/25000 [2:23:46<03:36,  2.80img/s]
#
#
# Processing Images:  98%|█████████▊| 24396/25000 [2:23:47<03:38,  2.77img/s]
#
#
# Processing Images:  98%|█████████▊| 24400/25000 [2:23:48<03:35,  2.78img/s]
#
#
# Processing Images:  98%|█████████▊| 24404/25000 [2:23:50<03:32,  2.80img/s]
#
#
# Processing Images:  98%|█████████▊| 24408/25000 [2:23:51<03:31,  2.80img/s]
#
#
# Processing Images:  98%|█████████▊| 24412/25000 [2:23:53<03:30,  2.79img/s]
#
#
# Processing Images:  98%|█████████▊| 24416/25000 [2:23:54<03:28,  2.80img/s]
#
#
# Processing Images:  98%|█████████▊| 24420/25000 [2:23:56<03:26,  2.81img/s]
#
#
# Processing Images:  98%|█████████▊| 24424/25000 [2:23:57<03:27,  2.78img/s]
#
#
# Processing Images:  98%|█████████▊| 24428/25000 [2:23:58<03:24,  2.79img/s]
#
#
# Processing Images:  98%|█████████▊| 24432/25000 [2:24:00<03:21,  2.82img/s]
#
#
# Processing Images:  98%|█████████▊| 24436/25000 [2:24:01<03:18,  2.84img/s]
#
#
# Processing Images:  98%|█████████▊| 24440/25000 [2:24:03<03:16,  2.85img/s]
#
#
# Processing Images:  98%|█████████▊| 24444/25000 [2:24:04<03:15,  2.85img/s]
#
#
# Processing Images:  98%|█████████▊| 24448/25000 [2:24:05<03:13,  2.86img/s]
#
#
# Processing Images:  98%|█████████▊| 24452/25000 [2:24:07<03:13,  2.83img/s]
#
#
# Processing Images:  98%|█████████▊| 24456/25000 [2:24:08<03:11,  2.83img/s]
#
#
# Processing Images:  98%|█████████▊| 24460/25000 [2:24:10<03:10,  2.84img/s]
#
#
# Processing Images:  98%|█████████▊| 24464/25000 [2:24:11<03:08,  2.84img/s]
#
#
# Processing Images:  98%|█████████▊| 24468/25000 [2:24:13<03:07,  2.83img/s]
#
#
# Processing Images:  98%|█████████▊| 24472/25000 [2:24:14<03:05,  2.84img/s]
#
#
# Processing Images:  98%|█████████▊| 24476/25000 [2:24:15<03:03,  2.85img/s]
#
#
# Processing Images:  98%|█████████▊| 24480/25000 [2:24:17<03:04,  2.83img/s]
#
#
# Processing Images:  98%|█████████▊| 24484/25000 [2:24:18<03:02,  2.83img/s]
#
#
# Processing Images:  98%|█████████▊| 24488/25000 [2:24:20<03:00,  2.84img/s]
#
#
# Processing Images:  98%|█████████▊| 24492/25000 [2:24:21<02:58,  2.85img/s]
#
#
# Processing Images:  98%|█████████▊| 24496/25000 [2:24:22<02:57,  2.85img/s]
#
#
# Processing Images:  98%|█████████▊| 24500/25000 [2:24:24<02:55,  2.85img/s]
#
#
# Processing Images:  98%|█████████▊| 24504/25000 [2:24:25<02:54,  2.84img/s]
#
#
# Processing Images:  98%|█████████▊| 24508/25000 [2:24:27<02:55,  2.81img/s]
#
#
# Processing Images:  98%|█████████▊| 24512/25000 [2:24:28<02:53,  2.81img/s]
#
#
# Processing Images:  98%|█████████▊| 24516/25000 [2:24:29<02:51,  2.82img/s]
#
#
# Processing Images:  98%|█████████▊| 24520/25000 [2:24:31<02:49,  2.83img/s]
#
#
# Processing Images:  98%|█████████▊| 24524/25000 [2:24:32<02:48,  2.83img/s]
#
#
# Processing Images:  98%|█████████▊| 24528/25000 [2:24:34<02:46,  2.84img/s]
#
#
# Processing Images:  98%|█████████▊| 24532/25000 [2:24:35<02:44,  2.84img/s]
#
#
# Processing Images:  98%|█████████▊| 24536/25000 [2:24:37<02:45,  2.80img/s]
#
#
# Processing Images:  98%|█████████▊| 24540/25000 [2:24:38<02:43,  2.81img/s]
#
#
# Processing Images:  98%|█████████▊| 24544/25000 [2:24:39<02:41,  2.83img/s]
#
#
# Processing Images:  98%|█████████▊| 24548/25000 [2:24:41<02:39,  2.84img/s]
#
#
# Processing Images:  98%|█████████▊| 24552/25000 [2:24:42<02:37,  2.85img/s]
#
#
# Processing Images:  98%|█████████▊| 24556/25000 [2:24:44<02:35,  2.86img/s]
#
#
# Processing Images:  98%|█████████▊| 24560/25000 [2:24:45<02:33,  2.86img/s]
#
#
# Processing Images:  98%|█████████▊| 24564/25000 [2:24:46<02:33,  2.84img/s]
#
#
# Processing Images:  98%|█████████▊| 24568/25000 [2:24:48<02:32,  2.84img/s]
#
#
# Processing Images:  98%|█████████▊| 24572/25000 [2:24:49<02:31,  2.83img/s]
#
#
# Processing Images:  98%|█████████▊| 24576/25000 [2:24:51<02:29,  2.84img/s]
#
#
# Processing Images:  98%|█████████▊| 24580/25000 [2:24:52<02:27,  2.85img/s]
#
#
# Processing Images:  98%|█████████▊| 24584/25000 [2:24:53<02:25,  2.85img/s]
#
#
# Processing Images:  98%|█████████▊| 24588/25000 [2:24:55<02:24,  2.86img/s]
#
#
# Processing Images:  98%|█████████▊| 24592/25000 [2:24:56<02:22,  2.85img/s]
#
#
# Processing Images:  98%|█████████▊| 24596/25000 [2:24:58<02:22,  2.84img/s]
#
#
# Processing Images:  98%|█████████▊| 24600/25000 [2:24:59<02:21,  2.84img/s]
#
#
# Processing Images:  98%|█████████▊| 24604/25000 [2:25:00<02:19,  2.83img/s]
#
#
# Processing Images:  98%|█████████▊| 24608/25000 [2:25:02<02:17,  2.84img/s]
#
#
# Processing Images:  98%|█████████▊| 24612/25000 [2:25:03<02:16,  2.84img/s]
#
#
# Processing Images:  98%|█████████▊| 24616/25000 [2:25:05<02:14,  2.85img/s]
#
#
# Processing Images:  98%|█████████▊| 24620/25000 [2:25:06<02:13,  2.86img/s]
#
#
# Processing Images:  98%|█████████▊| 24624/25000 [2:25:08<02:12,  2.83img/s]
#
#
# Processing Images:  99%|█████████▊| 24628/25000 [2:25:09<02:11,  2.84img/s]
#
#
# Processing Images:  99%|█████████▊| 24632/25000 [2:25:10<02:09,  2.84img/s]
#
#
# Processing Images:  99%|█████████▊| 24636/25000 [2:25:12<02:07,  2.85img/s]
#
#
# Processing Images:  99%|█████████▊| 24640/25000 [2:25:13<02:06,  2.85img/s]
#
#
# Processing Images:  99%|█████████▊| 24644/25000 [2:25:14<02:04,  2.86img/s]
#
#
# Processing Images:  99%|█████████▊| 24648/25000 [2:25:16<02:02,  2.86img/s]
#
#
# Processing Images:  99%|█████████▊| 24652/25000 [2:25:17<02:03,  2.83img/s]
#
#
# Processing Images:  99%|█████████▊| 24656/25000 [2:25:19<02:01,  2.84img/s]
#
#
# Processing Images:  99%|█████████▊| 24660/25000 [2:25:20<01:59,  2.84img/s]
#
#
# Processing Images:  99%|█████████▊| 24664/25000 [2:25:22<01:58,  2.85img/s]
#
#
# Processing Images:  99%|█████████▊| 24668/25000 [2:25:23<01:56,  2.85img/s]
#
#
# Processing Images:  99%|█████████▊| 24672/25000 [2:25:24<01:55,  2.85img/s]
#
#
# Processing Images:  99%|█████████▊| 24676/25000 [2:25:26<01:53,  2.85img/s]
#
#
# Processing Images:  99%|█████████▊| 24680/25000 [2:25:27<01:52,  2.85img/s]
#
#
# Processing Images:  99%|█████████▊| 24684/25000 [2:25:29<01:50,  2.85img/s]
#
#
# Processing Images:  99%|█████████▉| 24688/25000 [2:25:30<01:49,  2.86img/s]
#
#
# Processing Images:  99%|█████████▉| 24692/25000 [2:25:31<01:48,  2.85img/s]
#
#
# Processing Images:  99%|█████████▉| 24696/25000 [2:25:33<01:47,  2.84img/s]
#
#
# Processing Images:  99%|█████████▉| 24700/25000 [2:25:34<01:46,  2.82img/s]
#
#
# Processing Images:  99%|█████████▉| 24704/25000 [2:25:36<01:45,  2.81img/s]
#
#
# Processing Images:  99%|█████████▉| 24708/25000 [2:25:37<01:44,  2.79img/s]
#
#
# Processing Images:  99%|█████████▉| 24712/25000 [2:25:39<01:42,  2.81img/s]
#
#
# Processing Images:  99%|█████████▉| 24716/25000 [2:25:40<01:40,  2.82img/s]
#
#
# Processing Images:  99%|█████████▉| 24720/25000 [2:25:41<01:38,  2.83img/s]
#
#
# Processing Images:  99%|█████████▉| 24724/25000 [2:25:43<01:37,  2.82img/s]
#
#
# Processing Images:  99%|█████████▉| 24728/25000 [2:25:44<01:36,  2.81img/s]
#
#
# Processing Images:  99%|█████████▉| 24732/25000 [2:25:46<01:35,  2.80img/s]
#
#
# Processing Images:  99%|█████████▉| 24736/25000 [2:25:47<01:35,  2.77img/s]
#
#
# Processing Images:  99%|█████████▉| 24740/25000 [2:25:49<01:33,  2.78img/s]
#
#
# Processing Images:  99%|█████████▉| 24744/25000 [2:25:50<01:31,  2.79img/s]
#
#
# Processing Images:  99%|█████████▉| 24748/25000 [2:25:51<01:30,  2.80img/s]
#
#
# Processing Images:  99%|█████████▉| 24752/25000 [2:25:53<01:28,  2.80img/s]
#
#
# Processing Images:  99%|█████████▉| 24756/25000 [2:25:54<01:27,  2.80img/s]
#
#
# Processing Images:  99%|█████████▉| 24760/25000 [2:25:56<01:25,  2.80img/s]
#
#
# Processing Images:  99%|█████████▉| 24764/25000 [2:25:57<01:24,  2.78img/s]
#
#
# Processing Images:  99%|█████████▉| 24768/25000 [2:25:59<01:23,  2.79img/s]
#
#
# Processing Images:  99%|█████████▉| 24772/25000 [2:26:00<01:21,  2.81img/s]
#
#
# Processing Images:  99%|█████████▉| 24776/25000 [2:26:01<01:19,  2.82img/s]
#
#
# Processing Images:  99%|█████████▉| 24780/25000 [2:26:03<01:17,  2.83img/s]
#
#
# Processing Images:  99%|█████████▉| 24784/25000 [2:26:04<01:16,  2.83img/s]
#
#
# Processing Images:  99%|█████████▉| 24788/25000 [2:26:06<01:14,  2.85img/s]
#
#
# Processing Images:  99%|█████████▉| 24792/25000 [2:26:07<01:14,  2.81img/s]
#
#
# Processing Images:  99%|█████████▉| 24796/25000 [2:26:08<01:12,  2.83img/s]
#
#
# Processing Images:  99%|█████████▉| 24800/25000 [2:26:10<01:10,  2.83img/s]
#
#
# Processing Images:  99%|█████████▉| 24804/25000 [2:26:11<01:09,  2.82img/s]
#
#
# Processing Images:  99%|█████████▉| 24808/25000 [2:26:13<01:07,  2.84img/s]
#
#
# Processing Images:  99%|█████████▉| 24812/25000 [2:26:14<01:05,  2.85img/s]
#
#
# Processing Images:  99%|█████████▉| 24816/25000 [2:26:15<01:04,  2.86img/s]
#
#
# Processing Images:  99%|█████████▉| 24820/25000 [2:26:17<01:03,  2.83img/s]
#
#
# Processing Images:  99%|█████████▉| 24824/25000 [2:26:18<01:01,  2.84img/s]
#
#
# Processing Images:  99%|█████████▉| 24828/25000 [2:26:20<01:00,  2.85img/s]
#
#
# Processing Images:  99%|█████████▉| 24832/25000 [2:26:21<00:58,  2.86img/s]
#
#
# Processing Images:  99%|█████████▉| 24836/25000 [2:26:22<00:57,  2.86img/s]
#
#
# Processing Images:  99%|█████████▉| 24840/25000 [2:26:24<00:55,  2.86img/s]
#
#
# Processing Images:  99%|█████████▉| 24844/25000 [2:26:25<00:54,  2.87img/s]
#
#
# Processing Images:  99%|█████████▉| 24848/25000 [2:26:27<00:53,  2.84img/s]
#
#
# Processing Images:  99%|█████████▉| 24852/25000 [2:26:28<00:51,  2.85img/s]
#
#
# Processing Images:  99%|█████████▉| 24856/25000 [2:26:29<00:50,  2.85img/s]
#
#
# Processing Images:  99%|█████████▉| 24860/25000 [2:26:31<00:48,  2.86img/s]
#
#
# Processing Images:  99%|█████████▉| 24864/25000 [2:26:32<00:47,  2.85img/s]
#
#
# Processing Images:  99%|█████████▉| 24868/25000 [2:26:34<00:46,  2.84img/s]
#
#
# Processing Images:  99%|█████████▉| 24872/25000 [2:26:35<00:44,  2.85img/s]
#
#
# Processing Images: 100%|█████████▉| 24876/25000 [2:26:37<00:44,  2.81img/s]
#
#
# Processing Images: 100%|█████████▉| 24880/25000 [2:26:38<00:42,  2.83img/s]
#
#
# Processing Images: 100%|█████████▉| 24884/25000 [2:26:39<00:40,  2.85img/s]
#
#
# Processing Images: 100%|█████████▉| 24888/25000 [2:26:41<00:39,  2.86img/s]
#
#
# Processing Images: 100%|█████████▉| 24892/25000 [2:26:42<00:37,  2.86img/s]
#
#
# Processing Images: 100%|█████████▉| 24896/25000 [2:26:43<00:36,  2.87img/s]
#
#
# Processing Images: 100%|█████████▉| 24900/25000 [2:26:45<00:34,  2.86img/s]
#
#
# Processing Images: 100%|█████████▉| 24904/25000 [2:26:46<00:33,  2.84img/s]
#
#
# Processing Images: 100%|█████████▉| 24908/25000 [2:26:48<00:32,  2.83img/s]
#
#
# Processing Images: 100%|█████████▉| 24912/25000 [2:26:49<00:31,  2.83img/s]
#
#
# Processing Images: 100%|█████████▉| 24916/25000 [2:26:51<00:29,  2.83img/s]
#
#
# Processing Images: 100%|█████████▉| 24920/25000 [2:26:52<00:28,  2.83img/s]
#
#
# Processing Images: 100%|█████████▉| 24924/25000 [2:26:53<00:26,  2.83img/s]
#
#
# Processing Images: 100%|█████████▉| 24928/25000 [2:26:55<00:25,  2.84img/s]
#
#
# Processing Images: 100%|█████████▉| 24932/25000 [2:26:56<00:23,  2.85img/s]
#
#
# Processing Images: 100%|█████████▉| 24936/25000 [2:26:58<00:22,  2.83img/s]
#
#
# Processing Images: 100%|█████████▉| 24940/25000 [2:26:59<00:21,  2.84img/s]
#
#
# Processing Images: 100%|█████████▉| 24944/25000 [2:27:00<00:19,  2.84img/s]
#
#
# Processing Images: 100%|█████████▉| 24948/25000 [2:27:02<00:18,  2.86img/s]
#
#
# Processing Images: 100%|█████████▉| 24952/25000 [2:27:03<00:16,  2.86img/s]
#
#
# Processing Images: 100%|█████████▉| 24956/25000 [2:27:05<00:15,  2.87img/s]
#
#
# Processing Images: 100%|█████████▉| 24960/25000 [2:27:06<00:13,  2.88img/s]
#
#
# Processing Images: 100%|█████████▉| 24964/25000 [2:27:07<00:12,  2.85img/s]
#
#
# Processing Images: 100%|█████████▉| 24968/25000 [2:27:09<00:11,  2.86img/s]
#
#
# Processing Images: 100%|█████████▉| 24972/25000 [2:27:10<00:09,  2.86img/s]
#
#
# Processing Images: 100%|█████████▉| 24976/25000 [2:27:12<00:08,  2.87img/s]
#
#
# Processing Images: 100%|█████████▉| 24980/25000 [2:27:13<00:06,  2.88img/s]
#
#
# Processing Images: 100%|█████████▉| 24984/25000 [2:27:14<00:05,  2.88img/s]
#
#
# Processing Images: 100%|█████████▉| 24988/25000 [2:27:16<00:04,  2.88img/s]
#
#
# Processing Images: 100%|█████████▉| 24992/25000 [2:27:17<00:02,  2.87img/s]
#
#
# Processing Images: 100%|█████████▉| 24996/25000 [2:27:19<00:01,  2.86img/s]
#
#
# Processing Images: 100%|██████████| 25000/25000 [2:27:20<00:00,  2.83img/s]

# %%
import numpy as np

distances = [1, 2, 3, 4]
angles = [0, np.pi/4, np.pi/2, 3*np.pi/4]
angle_labels = [0, 45, 90, 135]   # for readable names

subbands = ["cA", "cH1", "cV1", "cD1", "cH2", "cV2", "cD2"]
props = ["contrast", "energy", "homogeneity", "correlation"]

feature_cols = []

for sb in subbands:
    for prop in props:
        # graycoprops output is shape (len(distances), len(angles))
        # .ravel() flattens with distance index first, then angle index
        for d in distances:
            for ang_deg in angle_labels:
                feature_cols.append(f"{sb}_{prop}_d{d}_a{ang_deg}")
    # one entropy per subband
    feature_cols.append(f"{sb}_entropy")

len(feature_cols)  # should be 455

df_features = pd.DataFrame(features, columns=feature_cols)
df = pd.concat(
    [pd.Series(paths, name="path"), df_features],
    axis=1
)

df.to_csv("glcm_features_fold1.csv", index=False)

# Save to Excel
df.to_excel("glcm_features_fold1.xlsx", index=False)
# Out:
# Processing Images:   1%|          | 191/25000 [2:34:43<334:56:16, 48.60s/img]
# Processing Images:   1%|          | 83/15000 [2:33:00<458:19:18, 110.61s/img]
